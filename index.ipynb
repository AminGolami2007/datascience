# %%
from wordcloud_fa import WordCloudFa
import matplotlib.pyplot as plt
import numpy as np



wordcloud=WordCloudFa(persian_normalize=True,include_numbers=False,background_color='black',width=800,height=800, font_path='IRANSans.ttf',margin=20,colormap='summer' )
wordcloud.add_stop_words_from_file("stopwords.txt")



# 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'

text='''


آیولرن، پلتفرمی نوین برای یادگیری عمیق هوش مصنوعی و برنامه‌ نویسی، در سال ۱۳۹۸ با هدف آموزش تخصصی برنامه نویسی و ایجاد فرصتی برابر برای یادگیری برای همه افراد، فارغ از موقعیت جغرافیایی و پیشینه تحصیلی، تاسیس شد.

از بدو تاسیس، آیولرن با ارائه دوره‌ های آموزشی با کیفیت بالا و استفاده از به‌روزترین متدهای آموزشی، به سرعت در میان علاقه‌مندان به هوش مصنوعی و برنامه‌ نویسی جایگاه ویژه‌ای پیدا کرد.

امروزه، آیولرن با بیش از ۱۰۰ هزار دانشجو از سراسر ایران و جهان، به یکی از بزرگترین پلتفرم‌های آموزشی آنلاین در حوزه هوش مصنوعی و برنامه‌ نویسی تبدیل شده .

آیولرن متعهد است که با ارائه آموزش‌  های با کیفیت و به‌ روز، به افراد در سراسر جهان کمک کند تا مهارت‌ های لازم برای موفقیت در دنیای امروز را به دست آورند.

ما به آینده و پتانسیل هوش مصنوعی برای حل برخی از بزرگترین چالش‌ های جهان ایمان داریم و مفتخریم که نقشی در آموزش نسل بعدی رهبران هوش مصنوعی ایفا می‌کنیم.

'''
wc = wordcloud.generate(text)
image = wc.to_image()
plt.imshow(image)
image.save('wordcloud.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 27
# ...

# %%
from deep_translator import GoogleTranslator

text='اه، این گوشی افتضاحه!'

en = GoogleTranslator(source='auto', target='en').translate(text)

print(en)
# Out:
# Oh, this phone is awful!

# %%
from transformers import pipeline
model = pipeline("sentiment-analysis")
data = "I love you"
model(data)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# WARNING:tensorflow:From c:\Users\mojaraddd\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9998656511306763}]

# %%
import pandas as pd


df=pd.read_csv('nazar.csv')

df.describe()



for text in df['nazaar']:
    print(text)
# Out:
# پیگیر و همراه
# در کل عالی سید
# خیلی منتور خوبی هست خیلی دلسوزه و واقعا تمام
# ایشون عالی هستند
# بسیار منتور خوب و عالی با حوصله جواب میدادن و
# عالی
# سلام ... وقت بخیر .... خانم مقصودی بسیار پیگیر
# اقای شهرستانی بسیار صبور و پیگیر و خوش برخورد
# هر جا که به مشکل خوردم کمک کرد
# منتوریه که همیشه مدام باهاتون در ارتباطه
# عالی بهترین منتور
# بسیار عالی
# ایشان عالیی هستن
# بینظیر
# بسیار صبور و پیگیر بودند.‌ممنونم از ایشون
# بهترین منتور
# بر خورد محترمانه و صمیمی
#
# پیگیری و اخلاق فوق العاده خانم محرابی باعث شد
# ناگفته پیداست........
#
# خیلی منتوره خوبیه. همیشه پاسخگوعه. همیشه خوب
# واقعا با اختلاف خیلی خیلی زیاد بهترین منتور ش
# بهترین منتور تکی تک
# عالل
# جیگر
# عالی بود از هر نظر و درد انجام پروژه ها همراه
# عالی
# خانم مریدی خیلی عالی بودند
# عالی
# بچه خوبیه باحاله
# آنلاین,پیگیر,کاربلد
# بهترین
# خانم نجفیان خیلی خوش برخورد هستند و سوالات من
# عالی
# بی نظیر
# بهترین منتور ❤️
# خیلی عالی و با جزعیات  توضیح میدهد ممنونمم
# مهربون , آنتایم , صمیمی , راحت و واقعی
# عالی
# ...

# %%
from deep_translator import GoogleTranslator
from transformers import pipeline

import pandas as pd


df=pd.read_csv('nazar.csv')



model = pipeline("sentiment-analysis")




for text in df['nazaar']:
    en = GoogleTranslator(source='auto', target='en').translate(text)
    out=model(en)
 
    if out[0]['label']=='POSITIVE':
        print("😊", round(out[0]['score']*100),'%')

    if out[0]['label']=='NEGATIVE':
        print("😔", round(out[0]['score']*100),'%')








# text='خیلی منتور خوبی هست خیلی دلسوزه و واقعا تمام'


# text='آنلاین,پیگیر,کاربلد'

# en = GoogleTranslator(source='auto', target='en').translate(text)

# out=model(en)
# if out[0]['label']=='POSITIVE':
#     print("😊", round(out[0]['score']*100),'%')

# if out[0]['label']=='NEGATIVE':
#     print("😔", round(out[0]['score']*100),'%')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 95 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😔 99 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 99 %
# 😊 98 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 97 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %
# 😊 100 %

# %%
text='این گوشی شما افتضاح هستش'

en = GoogleTranslator(source='auto', target='en').translate(text)

out=model(en)
if out[0]['label']=='POSITIVE':
    print("😊", round(out[0]['score']*100),'%')

if out[0]['label']=='NEGATIVE':
    print("😔", round(out[0]['score']*100),'%')
# Out:
# 😔 100 %

# %%
df=pd.read_csv('nazar.csv')

df.describe()


textKol=''
for text in df['nazaar']:
    textKol=textKol+' '+text

from wordcloud_fa import WordCloudFa
import matplotlib.pyplot as plt



wordcloud=WordCloudFa(persian_normalize=True,include_numbers=False,background_color='white',width=1400,height=800,stopwords=set(['خیلی','و','...','.','...','با']))
wordcloud.add_stop_words_from_file("stopwords.txt")


wc = wordcloud.generate(textKol)
image = wc.to_image()
plt.imshow(image)
image.save('wordcloud.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 19
#      15 wordcloud=WordCloudFa(persian_normalize=True,include_numbers=False,background_color='white',width=1400,height=800,stopwords=set(['خیلی','و','...','.','...','با']))
#      16 wordcloud.add_stop_words_from_file("stopwords.txt")
# ---> 19 wc = wordcloud.generate(textKol)
#      20 image = wc.to_image()
#      21 plt.imshow(image)
#
# File c:\Users\mojaraddd\AppData\Local\Programs\Python\Python310\lib\site-packages\wordcloud_fa\WordCloudFa.py:196, in WordCloudFa.generate(self, text)
#     190 def generate(self, text):
#     191     """
#     192     Generates wordcloud from a text. It is a wrapper for `generate_from_text` method.
#     193     :param text:
#     194     :return:
#     195     """
# --> 196     return self.generate_from_text(text)
#
# ...
